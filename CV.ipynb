# %%
import os
import cv2
import warnings
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torch.optim import Adam, Optimizer
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import TensorDataset, DataLoader, random_split

warnings.filterwarnings("ignore")

# %% [markdown]
# # Смотрим фичи классификации

# %% [markdown]
# ## Модель

# %%
class BaseCNN(nn.Module):
    def __init__(self, input_size=24):
        super(BaseCNN, self).__init__()

        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)

        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.flattened_size = (input_size // 4) * (input_size // 4) * 16

        self.fc = nn.Linear(self.flattened_size, 2)

    def forward(self, x, return_features=False):
        x = self.relu(self.conv1(x))
        x = self.pool(x)

        x = self.relu(self.conv2(x))
        x = self.pool(x)

        features = x.view(x.size(0), -1)
        out = self.fc(features)

        if return_features:
            return out, features
        return out

# %%
model = BaseCNN(input_size=24)
dummy_input = torch.randn(8, 1, 24, 24)

logits, features = model(dummy_input, return_features=True)

print("Logits shape:", logits.shape)  # [8, 2]
print("Features shape:", features.shape)  # [8, N]
# Out:
# Logits shape: torch.Size([8, 2])
# Features shape: torch.Size([8, 576])

# %% [markdown]
# ## Аннотирование

# %% [markdown]
# Функция для действий при нажатии на клавиши мыши

# %%
def click_event(event, x, y, flags, params):
    global data
    if event == cv2.EVENT_LBUTTONDOWN:
        new_row = pd.Series({'x1': x, 'y1': y, 'x2': None, 'y2': None, 'label': None})
        data = pd.concat([data, new_row.to_frame().T], ignore_index=True)
        print(f'ЛКМ: добавил точку ({x},{y}) как x1, y1')

    elif event == cv2.EVENT_RBUTTONDOWN:
        idx = data[data['x2'].isnull()].last_valid_index()
        if idx is not None:
            data.at[idx, 'x2'] = x
            data.at[idx, 'y2'] = y
            print(f'ПКМ: добавил точку ({x},{y}) как x2, y2')

# %% [markdown]
# /Функция для действий при нажатии на кнопку

# %%
def key_event():
    global data
    while True:
        key = cv2.waitKey(0) & 0xFF
        idx = data[data['label'].isnull()].last_valid_index()

        if key == ord('w') and idx is not None:
            data.at[idx, 'label'] = 1
            print('label = 1')
        elif key == ord('s') and idx is not None:
            data.at[idx, 'label'] = 0
            print('label = 0')
        elif key == ord('t'):
            save_patches()
            return 'continue'
        elif key == ord('q'):
            save_all_tensors()
            return 'end'

# %% [markdown]
# Функция для сохранения патчей

# %%
def save_patches():
    global current_img, data, all_tensors, all_labels

    for i, row in data.iterrows():
        if pd.isnull(row[['x1', 'y1', 'x2', 'y2', 'label']]).any():
            continue

        x1, y1, x2, y2 = map(int, [row['x1'], row['y1'], row['x2'], row['y2']])
        xmin, xmax = min(x1, x2), max(x1, x2)
        ymin, ymax = min(y1, y2), max(y1, y2)

        patch = current_img[ymin:ymax, xmin:xmax]
        patch_gray = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)
        patch_resized = cv2.resize(patch_gray, (24, 24))
        patch_tensor = torch.tensor(patch_resized, dtype=torch.float32).unsqueeze(0)

        patch_tensor /= 255.0

        all_tensors.append(patch_tensor)
        all_labels.append(int(row["label"]))

    data = pd.DataFrame(columns=['x1', 'y1', 'x2', 'y2', 'label'])

# %% [markdown]
# Функция для сохранения финальных тензоров

# %%
def save_all_tensors():
    global all_tensors, all_labels
    try:
        all_tensors_tensor = torch.stack(all_tensors)
        torch.save(all_tensors_tensor, 'CV_data/Train/images.pt')
        torch.save(all_labels, 'CV_data/Train/labels.pt')
        print('Сохранены все тензоры и лейблы')
    except Exception as e:
        print('Данные не были сохранены')

# %%
data = pd.DataFrame(columns=['x1', 'y1', 'x2', 'y2', 'label'])

photo_dir = 'CV_data/photos'
photos = [os.path.join(photo_dir, f) for f in os.listdir(photo_dir)]

output_dir = 'CV_data/Train'
os.makedirs(output_dir, exist_ok=True)

current_img = None

all_tensors = []
all_labels = []

for photo in photos:
    current_img = cv2.imread(photo)
    cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
    cv2.imshow('frame', current_img)

    cv2.setMouseCallback('frame', click_event)
    res = key_event()

    cv2.destroyAllWindows()

    if res == 'end':
        break
# Out:
# ЛКМ: добавил точку (965,1566) как x1, y1
# ПКМ: добавил точку (993,1618) как x2, y2
# label = 1
# ЛКМ: добавил точку (697,1230) как x1, y1
# ПКМ: добавил точку (717,1254) как x2, y2
# label = 1
# ЛКМ: добавил точку (472,2459) как x1, y1
# ПКМ: добавил точку (496,2499) как x2, y2
# label = 1
# ЛКМ: добавил точку (524,1707) как x1, y1
# ПКМ: добавил точку (548,1744) как x2, y2
# label = 1
# ЛКМ: добавил точку (1250,1159) как x1, y1
# ПКМ: добавил точку (1274,1190) как x2, y2
# label = 1
# ЛКМ: добавил точку (1527,370) как x1, y1
# ПКМ: добавил точку (1547,401) как x2, y2
# label = 1
# ЛКМ: добавил точку (1415,253) как x1, y1
# ПКМ: добавил точку (1436,280) как x2, y2
# label = 1
# ЛКМ: добавил точку (1567,2099) как x1, y1
# ПКМ: добавил точку (1585,2130) как x2, y2
# label = 1
# ЛКМ: добавил точку (1585,2277) как x1, y1
# ПКМ: добавил точку (1608,2311) как x2, y2
# label = 1
# ЛКМ: добавил точку (1620,2321) как x1, y1
# ПКМ: добавил точку (1637,2351) как x2, y2
# label = 1
# ЛКМ: добавил точку (1290,2339) как x1, y1
# ПКМ: добавил точку (1310,2364) как x2, y2
# label = 1
# ЛКМ: добавил точку (1088,1214) как x1, y1
# ПКМ: добавил точку (1100,1248) как x2, y2
# label = 0
# ЛКМ: добавил точку (993,1128) как x1, y1
# ПКМ: добавил точку (1008,1162) как x2, y2
# label = 0
# ЛКМ: добавил точку (1162,780) как x1, y1
# ПКМ: добавил точку (1182,804) как x2, y2
# label = 0
# ЛКМ: добавил точку (1130,468) как x1, y1
# ПКМ: добавил точку (1152,499) как x2, y2
# label = 0
# ЛКМ: добавил точку (1306,40) как x1, y1
# ПКМ: добавил точку (1326,89) как x2, y2
# label = 0
# ЛКМ: добавил точку (1338,37) как x1, y1
# ПКМ: добавил точку (1370,102) как x2, y2
# label = 0
# ЛКМ: добавил точку (737,96) как x1, y1
# ПКМ: добавил точку (773,148) как x2, y2
# label = 0
# ЛКМ: добавил точку (781,373) как x1, y1
# ПКМ: добавил точку (825,490) как x2, y2
# label = 0
# ЛКМ: добавил точку (799,733) как x1, y1
# ПКМ: добавил точку (859,832) как x2, y2
# label = 0
# ЛКМ: добавил точку (817,1082) как x1, y1
# ПКМ: добавил точку (882,1183) как x2, y2
# label = 0
# ЛКМ: добавил точку (531,909) как x1, y1
# ПКМ: добавил точку (588,974) как x2, y2
# label = 0
# ЛКМ: добавил точку (851,1077) как x1, y1
# ПКМ: добавил точку (878,1131) как x2, y2
# label = 1
# ЛКМ: добавил точку (1649,601) как x1, y1
# ПКМ: добавил точку (1686,670) как x2, y2
# label = 1
# ЛКМ: добавил точку (1343,420) как x1, y1
# ПКМ: добавил точку (1378,479) как x2, y2
# label = 1
# ЛКМ: добавил точку (1249,274) как x1, y1
# ПКМ: добавил точку (1287,330) как x2, y2
# label = 1
# ЛКМ: добавил точку (170,1357) как x1, y1
# ПКМ: добавил точку (206,1413) как x2, y2
# label = 1
# ЛКМ: добавил точку (225,536) как x1, y1
# ПКМ: добавил точку (251,589) как x2, y2
# label = 1
# ЛКМ: добавил точку (221,152) как x1, y1
# ПКМ: добавил точку (247,199) как x2, y2
# label = 1
# ЛКМ: добавил точку (1307,2217) как x1, y1
# ПКМ: добавил точку (1341,2294) как x2, y2
# label = 0
# ЛКМ: добавил точку (1372,2110) как x1, y1
# ПКМ: добавил точку (1423,2238) как x2, y2
# label = 0
# ЛКМ: добавил точку (1255,1669) как x1, y1
# ПКМ: добавил точку (1306,1762) как x2, y2
# label = 0
# ЛКМ: добавил точку (1275,1419) как x1, y1
# ПКМ: добавил точку (1331,1503) как x2, y2
# label = 0
# ЛКМ: добавил точку (1327,485) как x1, y1
# ПКМ: добавил точку (1423,619) как x2, y2
# label = 0
# ЛКМ: добавил точку (1684,806) как x1, y1
# ПКМ: добавил точку (1753,922) как x2, y2
# label = 0
# ЛКМ: добавил точку (767,1550) как x1, y1
# ПКМ: добавил точку (839,1672) как x2, y2
# label = 0
# ЛКМ: добавил точку (766,821) как x1, y1
# ПКМ: добавил точку (829,997) как x2, y2
# label = 0
# ЛКМ: добавил точку (943,789) как x1, y1
# ПКМ: добавил точку (983,875) как x2, y2
# label = 0
# ЛКМ: добавил точку (859,414) как x1, y1
# ПКМ: добавил точку (920,533) как x2, y2
# label = 0
# ЛКМ: добавил точку (168,1044) как x1, y1
# ПКМ: добавил точку (226,1140) как x2, y2
# label = 0
# ЛКМ: добавил точку (48,720) как x1, y1
# ПКМ: добавил точку (132,890) как x2, y2
# label = 0
# ЛКМ: добавил точку (51,1381) как x1, y1
# ПКМ: добавил точку (126,1595) как x2, y2
# label = 0
# ЛКМ: добавил точку (967,1253) как x1, y1
# ПКМ: добавил точку (1049,1407) как x2, y2
# label = 0
# ЛКМ: добавил точку (975,565) как x1, y1
# ПКМ: добавил точку (1079,714) как x2, y2
# label = 0
# ЛКМ: добавил точку (1527,1532) как x1, y1
# ПКМ: добавил точку (1592,1672) как x2, y2
# label = 0
# ЛКМ: добавил точку (693,2327) как x1, y1
# ПКМ: добавил точку (733,2386) как x2, y2
# label = 1
# ЛКМ: добавил точку (573,199) как x1, y1
# ПКМ: добавил точку (612,274) как x2, y2
# label = 1
# ЛКМ: добавил точку (668,199) как x1, y1
# ПКМ: добавил точку (710,286) как x2, y2
# label = 1
# ЛКМ: добавил точку (847,262) как x1, y1
# ПКМ: добавил точку (876,321) как x2, y2
# label = 0
# ЛКМ: добавил точку (1444,95) как x1, y1
# ПКМ: добавил точку (1475,131) как x2, y2
# label = 1
# ЛКМ: добавил точку (1462,152) как x1, y1
# ПКМ: добавил точку (1492,196) как x2, y2
# label = 1
# ЛКМ: добавил точку (1378,1410) как x1, y1
# ПКМ: добавил точку (1410,1467) как x2, y2
# label = 1
# ЛКМ: добавил точку (1374,1166) как x1, y1
# ПКМ: добавил точку (1411,1253) как x2, y2
# label = 1
# ЛКМ: добавил точку (1472,905) как x1, y1
# ПКМ: добавил точку (1501,982) как x2, y2
# label = 1
# ЛКМ: добавил точку (1448,664) как x1, y1
# ПКМ: добавил точку (1480,741) как x2, y2
# label = 1
# ЛКМ: добавил точку (1620,857) как x1, y1
# ПКМ: добавил точку (1650,925) как x2, y2
# label = 1
# ЛКМ: добавил точку (434,277) как x1, y1
# ПКМ: добавил точку (460,324) как x2, y2
# label = 1
# ЛКМ: добавил точку (391,1538) как x1, y1
# ПКМ: добавил точку (422,1595) как x2, y2
# label = 1
# ЛКМ: добавил точку (525,1399) как x1, y1
# ПКМ: добавил точку (553,1449) как x2, y2
# label = 0
# ЛКМ: добавил точку (710,1776) как x1, y1
# ПКМ: добавил точку (782,1916) как x2, y2
# label = 0
# ЛКМ: добавил точку (706,2404) как x1, y1
# ПКМ: добавил точку (741,2491) как x2, y2
# label = 0
# ЛКМ: добавил точку (1013,2380) как x1, y1
# ПКМ: добавил точку (1060,2491) как x2, y2
# label = 0
# ЛКМ: добавил точку (1235,2315) как x1, y1
# ПКМ: добавил точку (1301,2434) как x2, y2
# label = 0
# ЛКМ: добавил точку (1689,744) как x1, y1
# ПКМ: добавил точку (1724,869) как x2, y2
# label = 0
# ЛКМ: добавил точку (961,161) как x1, y1
# ПКМ: добавил точку (1009,232) как x2, y2
# label = 0
# ЛКМ: добавил точку (743,1294) как x1, y1
# ПКМ: добавил точку (783,1360) как x2, y2
# label = 0
# ЛКМ: добавил точку (801,1833) как x1, y1
# ПКМ: добавил точку (832,1907) как x2, y2
# label = 0
# ЛКМ: добавил точку (1242,1550) как x1, y1
# ПКМ: добавил точку (1286,1640) как x2, y2
# label = 0
# ЛКМ: добавил точку (1565,1419) как x1, y1
# ПКМ: добавил точку (1622,1535) как x2, y2
# label = 0
# ЛКМ: добавил точку (1634,2116) как x1, y1
# ПКМ: добавил точку (1722,2339) как x2, y2
# label = 0
# ЛКМ: добавил точку (1533,2190) как x1, y1
# ПКМ: добавил точку (1657,2431) как x2, y2
# label = 0
# ЛКМ: добавил точку (851,684) как x1, y1
# ПКМ: добавил точку (890,774) как x2, y2
# label = 0
# ЛКМ: добавил точку (1138,1000) как x1, y1
# ПКМ: добавил точку (1231,1241) как x2, y2
# label = 0
# ЛКМ: добавил точку (593,280) как x1, y1
# ПКМ: добавил точку (674,420) как x2, y2
# label = 0
# ЛКМ: добавил точку (317,330) как x1, y1
# ПКМ: добавил точку (402,494) как x2, y2
# label = 0
# ЛКМ: добавил точку (354,1595) как x1, y1
# ПКМ: добавил точку (403,1708) как x2, y2
# label = 0
# ЛКМ: добавил точку (852,941) как x1, y1
# ПКМ: добавил точку (900,1010) как x2, y2
# label = 1
# ЛКМ: добавил точку (891,1033) как x1, y1
# ПКМ: добавил точку (934,1105) как x2, y2
# label = 1
# ЛКМ: добавил точку (907,887) как x1, y1
# ПКМ: добавил точку (936,933) как x2, y2
# label = 1
# ЛКМ: добавил точку (1527,1613) как x1, y1
# ПКМ: добавил точку (1556,1664) как x2, y2
# label = 1
# ЛКМ: добавил точку (1184,181) как x1, y1
# ПКМ: добавил точку (1227,273) как x2, y2
# label = 1
# ЛКМ: добавил точку (851,258) как x1, y1
# ПКМ: добавил точку (883,336) как x2, y2
# label = 1
# ЛКМ: добавил точку (971,29) как x1, y1
# ПКМ: добавил точку (1003,75) как x2, y2
# label = 1
# ЛКМ: добавил точку (585,2057) как x1, y1
# ПКМ: добавил точку (648,2166) как x2, y2
# label = 1
# ЛКМ: добавил точку (1102,1082) как x1, y1
# ПКМ: добавил точку (1176,1277) как x2, y2
# label = 0
# ЛКМ: добавил точку (1444,697) как x1, y1
# ПКМ: добавил точку (1492,815) как x2, y2
# label = 0
# ЛКМ: добавил точку (1604,717) как x1, y1
# ПКМ: добавил точку (1642,801) как x2, y2
# label = 0
# ЛКМ: добавил точку (1605,514) как x1, y1
# ПКМ: добавил точку (1654,637) как x2, y2
# label = 0
# ЛКМ: добавил точку (692,1165) как x1, y1
# ПКМ: добавил точку (735,1257) как x2, y2
# label = 0
# ЛКМ: добавил точку (1210,1815) как x1, y1
# ПКМ: добавил точку (1262,1963) как x2, y2
# label = 0
# ЛКМ: добавил точку (1452,1945) как x1, y1
# ПКМ: добавил точку (1511,2074) как x2, y2
# label = 0
# ЛКМ: добавил точку (1483,1116) как x1, y1
# ПКМ: добавил точку (1536,1227) как x2, y2
# label = 0
# ЛКМ: добавил точку (1126,706) как x1, y1
# ПКМ: добавил точку (1170,792) как x2, y2
# label = 0
# ЛКМ: добавил точку (840,438) как x1, y1
# ПКМ: добавил точку (890,530) как x2, y2
# label = 0
# ЛКМ: добавил точку (564,530) как x1, y1
# ПКМ: добавил точку (613,629) как x2, y2
# label = 0
# ЛКМ: добавил точку (383,592) как x1, y1
# ПКМ: добавил точку (439,712) как x2, y2
# label = 0
# ЛКМ: добавил точку (275,1054) как x1, y1
# ПКМ: добавил точку (322,1153) как x2, y2
# label = 0
# ЛКМ: добавил точку (621,553) как x1, y1
# ПКМ: добавил точку (686,661) как x2, y2
# label = 1
# ЛКМ: добавил точку (604,443) как x1, y1
# ПКМ: добавил точку (649,533) как x2, y2
# label = 1
# ЛКМ: добавил точку (230,1009) как x1, y1
# ПКМ: добавил точку (270,1086) как x2, y2
# label = 1
# ЛКМ: добавил точку (557,1146) как x1, y1
# ПКМ: добавил точку (604,1241) как x2, y2
# label = 0
# ЛКМ: добавил точку (811,1271) как x1, y1
# ПКМ: добавил точку (868,1390) как x2, y2
# label = 0
# ЛКМ: добавил точку (1281,1440) как x1, y1
# ПКМ: добавил точку (1346,1571) как x2, y2
# label = 0
# ЛКМ: добавил точку (765,256) как x1, y1
# ПКМ: добавил точку (802,327) как x2, y2
# label = 1
# ЛКМ: добавил точку (1571,1596) как x1, y1
# ПКМ: добавил точку (1617,1695) как x2, y2
# label = 0
# ЛКМ: добавил точку (1210,1985) как x1, y1
# ПКМ: добавил точку (1258,2102) как x2, y2
# label = 0
# ЛКМ: добавил точку (1456,1214) как x1, y1
# ПКМ: добавил точку (1483,1297) как x2, y2
# label = 0
# ЛКМ: добавил точку (1664,1262) как x1, y1
# ПКМ: добавил точку (1731,1464) как x2, y2
# label = 0
# ЛКМ: добавил точку (727,1664) как x1, y1
# ПКМ: добавил точку (790,1781) как x2, y2
# label = 0
# ЛКМ: добавил точку (769,1390) как x1, y1
# ПКМ: добавил точку (848,1538) как x2, y2
# label = 0
# ЛКМ: добавил точку (301,1618) как x1, y1
# ПКМ: добавил точку (331,1673) как x2, y2
# label = 1
# ЛКМ: добавил точку (1588,565) как x1, y1
# ПКМ: добавил точку (1629,657) как x2, y2
# label = 1
# ЛКМ: добавил точку (520,240) как x1, y1
# ПКМ: добавил точку (551,305) как x2, y2
# label = 1
# ЛКМ: добавил точку (952,1834) как x1, y1
# ПКМ: добавил точку (983,1895) как x2, y2
# label = 1
# ЛКМ: добавил точку (995,881) как x1, y1
# ПКМ: добавил точку (1036,955) как x2, y2
# label = 1
# ЛКМ: добавил точку (789,780) как x1, y1
# ПКМ: добавил точку (839,863) как x2, y2
# label = 1
# ЛКМ: добавил точку (1414,872) как x1, y1
# ПКМ: добавил точку (1463,943) как x2, y2
# label = 1
# ЛКМ: добавил точку (1464,988) как x1, y1
# ПКМ: добавил точку (1497,1038) как x2, y2
# label = 1
# ЛКМ: добавил точку (1564,1166) как x1, y1
# ПКМ: добавил точку (1591,1208) как x2, y2
# label = 1
# ЛКМ: добавил точку (1104,250) как x1, y1
# ПКМ: добавил точку (1137,312) как x2, y2
# label = 1
# ЛКМ: добавил точку (617,506) как x1, y1
# ПКМ: добавил точку (653,553) как x2, y2
# label = 1
# ЛКМ: добавил точку (1125,1021) как x1, y1
# ПКМ: добавил точку (1172,1080) как x2, y2
# label = 0
# ЛКМ: добавил точку (1329,747) как x1, y1
# ПКМ: добавил точку (1392,881) как x2, y2
# label = 0
# ЛКМ: добавил точку (1508,661) как x1, y1
# ПКМ: добавил точку (1561,789) как x2, y2
# label = 0
# ЛКМ: добавил точку (858,812) как x1, y1
# ПКМ: добавил точку (896,893) как x2, y2
# label = 0
# ЛКМ: добавил точку (545,1196) как x1, y1
# ПКМ: добавил точку (616,1321) как x2, y2
# label = 0
# ЛКМ: добавил точку (234,2336) как x1, y1
# ПКМ: добавил точку (263,2376) как x2, y2
# label = 1
# ЛКМ: добавил точку (829,63) как x1, y1
# ПКМ: добавил точку (860,115) как x2, y2
# label = 1
# ЛКМ: добавил точку (1684,887) как x1, y1
# ПКМ: добавил точку (1709,933) как x2, y2
# label = 0
# ЛКМ: добавил точку (1335,1922) как x1, y1
# ПКМ: добавил точку (1380,1994) как x2, y2
# label = 1
# ЛКМ: добавил точку (696,893) как x1, y1
# ПКМ: добавил точку (755,988) как x2, y2
# label = 0
# ЛКМ: добавил точку (1314,512) как x1, y1
# ПКМ: добавил точку (1366,598) как x2, y2
# label = 0
# ЛКМ: добавил точку (593,1044) как x1, y1
# ПКМ: добавил точку (629,1104) как x2, y2
# label = 1
# ЛКМ: добавил точку (821,1071) как x1, y1
# ПКМ: добавил точку (852,1134) как x2, y2
# label = 1
# ЛКМ: добавил точку (996,2035) как x1, y1
# ПКМ: добавил точку (1041,2113) как x2, y2
# label = 1
# ЛКМ: добавил точку (1368,2017) как x1, y1
# ПКМ: добавил точку (1419,2083) как x2, y2
# label = 1
# ЛКМ: добавил точку (741,1226) как x1, y1
# ПКМ: добавил точку (775,1288) как x2, y2
# label = 1
# ЛКМ: добавил точку (1360,229) как x1, y1
# ПКМ: добавил точку (1399,318) как x2, y2
# label = 1
# ЛКМ: добавил точку (943,305) как x1, y1
# ПКМ: добавил точку (968,364) как x2, y2
# label = 1
# ЛКМ: добавил точку (916,299) как x1, y1
# ПКМ: добавил точку (942,348) как x2, y2
# label = 1
# ЛКМ: добавил точку (1501,2025) как x1, y1
# ПКМ: добавил точку (1531,2086) как x2, y2
# label = 1
# ЛКМ: добавил точку (1239,1131) как x1, y1
# ПКМ: добавил точку (1278,1205) как x2, y2
# label = 0
# ЛКМ: добавил точку (1402,1029) как x1, y1
# ПКМ: добавил точку (1444,1134) как x2, y2
# label = 0
# ЛКМ: добавил точку (561,958) как x1, y1
# ПКМ: добавил точку (598,1029) как x2, y2
# label = 0
# ЛКМ: добавил точку (589,129) как x1, y1
# ПКМ: добавил точку (624,166) как x2, y2
# label = 1
# ЛКМ: добавил точку (359,57) как x1, y1
# ПКМ: добавил точку (407,126) как x2, y2
# label = 1
# ЛКМ: добавил точку (674,100) как x1, y1
# ПКМ: добавил точку (706,172) как x2, y2
# label = 1
# ЛКМ: добавил точку (1189,1354) как x1, y1
# ПКМ: добавил точку (1225,1425) как x2, y2
# label = 0
# ЛКМ: добавил точку (1257,350) как x1, y1
# ПКМ: добавил точку (1298,402) как x2, y2
# label = 1
# ЛКМ: добавил точку (1322,252) как x1, y1
# ПКМ: добавил точку (1362,341) как x2, y2
# label = 1
# ЛКМ: добавил точку (766,92) как x1, y1
# ПКМ: добавил точку (809,146) как x2, y2
# label = 1
# ЛКМ: добавил точку (672,304) как x1, y1
# ПКМ: добавил точку (697,347) как x2, y2
# label = 1
# ЛКМ: добавил точку (378,2152) как x1, y1
# ПКМ: добавил точку (410,2229) как x2, y2
# label = 1
# ЛКМ: добавил точку (1307,1232) как x1, y1
# ПКМ: добавил точку (1337,1279) как x2, y2
# label = 1
# ЛКМ: добавил точку (1241,443) как x1, y1
# ПКМ: добавил точку (1277,509) как x2, y2
# label = 1
# ЛКМ: добавил точку (557,695) как x1, y1
# ПКМ: добавил точку (581,746) как x2, y2
# label = 1
# ЛКМ: добавил точку (1333,539) как x1, y1
# ПКМ: добавил точку (1366,603) как x2, y2
# label = 1
# ЛКМ: добавил точку (1209,660) как x1, y1
# ПКМ: добавил точку (1239,714) как x2, y2
# label = 1
# ЛКМ: добавил точку (922,1817) как x1, y1
# ПКМ: добавил точку (946,1881) как x2, y2
# label = 0
# ЛКМ: добавил точку (1290,1664) как x1, y1
# ПКМ: добавил точку (1339,1801) как x2, y2
# label = 0
# ЛКМ: добавил точку (1458,833) как x1, y1
# ПКМ: добавил точку (1529,985) как x2, y2
# label = 0
# ЛКМ: добавил точку (649,1237) как x1, y1
# ПКМ: добавил точку (690,1313) как x2, y2
# label = 1
# ЛКМ: добавил точку (707,628) как x1, y1
# ПКМ: добавил точку (742,679) как x2, y2
# label = 1
# ЛКМ: добавил точку (810,475) как x1, y1
# ПКМ: добавил точку (838,526) как x2, y2
# label = 1
# ЛКМ: добавил точку (825,1460) как x1, y1
# ПКМ: добавил точку (848,1521) как x2, y2
# label = 1
# ЛКМ: добавил точку (759,1396) как x1, y1
# ПКМ: добавил точку (787,1451) как x2, y2
# label = 1
# ЛКМ: добавил точку (834,1135) как x1, y1
# ПКМ: добавил точку (860,1192) как x2, y2
# label = 1
# ЛКМ: добавил точку (975,1023) как x1, y1
# ПКМ: добавил точку (997,1068) как x2, y2
# label = 1
# ЛКМ: добавил точку (531,864) как x1, y1
# ПКМ: добавил точку (553,912) как x2, y2
# label = 1
# ЛКМ: добавил точку (277,1753) как x1, y1
# ПКМ: добавил точку (306,1820) как x2, y2
# label = 1
# ЛКМ: добавил точку (368,759) как x1, y1
# ПКМ: добавил точку (399,826) как x2, y2
# ЛКМ: добавил точку (399,826) как x1, y1
# label = 1
# ЛКМ: добавил точку (1172,1384) как x1, y1
# ПКМ: добавил точку (1218,1461) как x2, y2
# label = 0
# ЛКМ: добавил точку (1347,811) как x1, y1
# ПКМ: добавил точку (1386,906) как x2, y2
# label = 0
# ЛКМ: добавил точку (1588,666) как x1, y1
# ПКМ: добавил точку (1638,786) как x2, y2
# label = 0
# ЛКМ: добавил точку (822,586) как x1, y1
# ПКМ: добавил точку (852,652) как x2, y2
# label = 1
# ЛКМ: добавил точку (372,655) как x1, y1
# ПКМ: добавил точку (406,720) как x2, y2
# label = 1
# ЛКМ: добавил точку (815,919) как x1, y1
# ПКМ: добавил точку (848,988) как x2, y2
# label = 1
# ЛКМ: добавил точку (1501,655) как x1, y1
# ПКМ: добавил точку (1544,744) как x2, y2
# label = 1
# ЛКМ: добавил точку (1118,1082) как x1, y1
# ПКМ: добавил точку (1168,1183) как x2, y2
# label = 0
# ЛКМ: добавил точку (1436,841) как x1, y1
# ПКМ: добавил точку (1483,958) как x2, y2
# label = 0
# ЛКМ: добавил точку (731,607) как x1, y1
# ПКМ: добавил точку (778,724) как x2, y2
# label = 0
# ЛКМ: добавил точку (469,623) как x1, y1
# ПКМ: добавил точку (525,718) как x2, y2
# label = 0
# ЛКМ: добавил точку (588,384) как x1, y1
# ПКМ: добавил точку (626,449) как x2, y2
# label = 1
# ЛКМ: добавил точку (563,1663) как x1, y1
# ПКМ: добавил точку (602,1744) как x2, y2
# label = 1
# ЛКМ: добавил точку (270,357) как x1, y1
# ПКМ: добавил точку (314,423) как x2, y2
# label = 1
# ЛКМ: добавил точку (886,577) как x1, y1
# ПКМ: добавил точку (927,660) как x2, y2
# label = 1
# ЛКМ: добавил точку (1069,339) как x1, y1
# ПКМ: добавил точку (1116,413) как x2, y2
# label = 1
# ЛКМ: добавил точку (1122,209) как x1, y1
# ПКМ: добавил точку (1164,304) как x2, y2
# label = 1
# ЛКМ: добавил точку (1250,402) как x1, y1
# ПКМ: добавил точку (1290,473) как x2, y2
# label = 1
# ЛКМ: добавил точку (1318,531) как x1, y1
# ПКМ: добавил точку (1346,594) как x2, y2
# label = 1
# ЛКМ: добавил точку (1406,407) как x1, y1
# ПКМ: добавил точку (1436,471) как x2, y2
# label = 1
# ЛКМ: добавил точку (1367,1087) как x1, y1
# ПКМ: добавил точку (1395,1145) как x2, y2
# label = 1
# ЛКМ: добавил точку (1257,1050) как x1, y1
# ПКМ: добавил точку (1294,1122) как x2, y2
# label = 1
# ЛКМ: добавил точку (1142,1085) как x1, y1
# ПКМ: добавил точку (1176,1156) как x2, y2
# label = 1
# ЛКМ: добавил точку (1234,1142) как x1, y1
# ПКМ: добавил точку (1267,1199) как x2, y2
# label = 1
# ЛКМ: добавил точку (1370,1392) как x1, y1
# ПКМ: добавил точку (1398,1440) как x2, y2
# label = 1
# ЛКМ: добавил точку (829,1750) как x1, y1
# ПКМ: добавил точку (862,1822) как x2, y2
# label = 1
# ЛКМ: добавил точку (690,1185) как x1, y1
# ПКМ: добавил точку (727,1265) как x2, y2
# label = 1
# ЛКМ: добавил точку (572,1007) как x1, y1
# ПКМ: добавил точку (609,1085) как x2, y2
# label = 1
# ЛКМ: добавил точку (460,614) как x1, y1
# ПКМ: добавил точку (489,671) как x2, y2
# label = 1
# ЛКМ: добавил точку (1579,1833) как x1, y1
# ПКМ: добавил точку (1625,1905) как x2, y2
# label = 0
# ЛКМ: добавил точку (1587,1042) как x1, y1
# ПКМ: добавил точку (1629,1128) как x2, y2
# label = 0
# ЛКМ: добавил точку (851,1452) как x1, y1
# ПКМ: добавил точку (878,1512) как x2, y2
# label = 1
# ЛКМ: добавил точку (1126,1090) как x1, y1
# ПКМ: добавил точку (1162,1159) как x2, y2
# label = 1
# ЛКМ: добавил точку (1454,970) как x1, y1
# ПКМ: добавил точку (1493,1047) как x2, y2
# label = 1
# ЛКМ: добавил точку (332,1440) как x1, y1
# ПКМ: добавил точку (363,1492) как x2, y2
# label = 1
# ЛКМ: добавил точку (525,1412) как x1, y1
# ПКМ: добавил точку (551,1460) как x2, y2
# label = 1
# ЛКМ: добавил точку (854,1452) как x1, y1
# ПКМ: добавил точку (882,1506) как x2, y2
# label = 1
# ЛКМ: добавил точку (680,1476) как x1, y1
# ПКМ: добавил точку (719,1532) как x2, y2
# label = 1
# ЛКМ: добавил точку (1015,1319) как x1, y1
# ПКМ: добавил точку (1049,1396) как x2, y2
# ЛКМ: добавил точку (1049,1396) как x1, y1
# ЛКМ: добавил точку (1198,92) как x1, y1
# ПКМ: добавил точку (1235,170) как x2, y2
# label = 1
# ЛКМ: добавил точку (1012,1325) как x1, y1
# ПКМ: добавил точку (1048,1390) как x2, y2
# label = 1
# ЛКМ: добавил точку (1342,1507) как x1, y1
# ПКМ: добавил точку (1376,1559) как x2, y2
# label = 1
# ЛКМ: добавил точку (1298,1732) как x1, y1
# ПКМ: добавил точку (1331,1763) как x2, y2
# label = 1
# ЛКМ: добавил точку (1427,1975) как x1, y1
# ПКМ: добавил точку (1454,2028) как x2, y2
# label = 1
# ЛКМ: добавил точку (1366,2262) как x1, y1
# ПКМ: добавил точку (1403,2284) как x2, y2
# label = 1
# ЛКМ: добавил точку (672,2265) как x1, y1
# ПКМ: добавил точку (700,2308) как x2, y2
# label = 1
# ЛКМ: добавил точку (636,1966) как x1, y1
# ПКМ: добавил точку (662,2003) как x2, y2
# label = 1
# ЛКМ: добавил точку (298,746) как x1, y1
# ПКМ: добавил точку (331,792) как x2, y2
# label = 0
# ЛКМ: добавил точку (432,767) как x1, y1
# ПКМ: добавил точку (480,912) как x2, y2
# label = 0
# ЛКМ: добавил точку (1202,2049) как x1, y1
# ПКМ: добавил точку (1251,2143) как x2, y2
# label = 1
# ЛКМ: добавил точку (1293,2029) как x1, y1
# ПКМ: добавил точку (1331,2100) как x2, y2
# label = 1
# ЛКМ: добавил точку (1532,1897) как x1, y1
# ПКМ: добавил точку (1564,1963) как x2, y2
# label = 1
# ЛКМ: добавил точку (625,1056) как x1, y1
# ПКМ: добавил точку (696,1174) как x2, y2
# label = 0
# ЛКМ: добавил точку (851,690) как x1, y1
# ПКМ: добавил точку (898,797) как x2, y2
# label = 0
# ЛКМ: добавил точку (487,396) как x1, y1
# ПКМ: добавил точку (516,449) как x2, y2
# label = 1
# ЛКМ: добавил точку (1339,2089) как x1, y1
# ПКМ: добавил точку (1375,2136) как x2, y2
# label = 1
# ЛКМ: добавил точку (961,2083) как x1, y1
# ПКМ: добавил точку (987,2119) как x2, y2
# label = 1
# ЛКМ: добавил точку (593,703) как x1, y1
# ПКМ: добавил точку (646,801) как x2, y2
# label = 1
# ЛКМ: добавил точку (1333,2227) как x1, y1
# ПКМ: добавил точку (1380,2321) как x2, y2
# label = 1
# ЛКМ: добавил точку (176,1770) как x1, y1
# ПКМ: добавил точку (221,1854) как x2, y2
# label = 1
# ЛКМ: добавил точку (205,1592) как x1, y1
# ПКМ: добавил точку (241,1687) как x2, y2
# label = 1
# ЛКМ: добавил точку (207,353) как x1, y1
# ПКМ: добавил точку (249,425) как x2, y2
# label = 1
# ЛКМ: добавил точку (874,399) как x1, y1
# ПКМ: добавил точку (938,514) как x2, y2
# label = 0
# ЛКМ: добавил точку (612,1018) как x1, y1
# ПКМ: добавил точку (650,1080) как x2, y2
# label = 1
# ЛКМ: добавил точку (315,988) как x1, y1
# ПКМ: добавил точку (356,1044) как x2, y2
# label = 1
# ЛКМ: добавил точку (689,515) как x1, y1
# ПКМ: добавил точку (738,589) как x2, y2
# ЛКМ: добавил точку (763,351) как x1, y1
# ПКМ: добавил точку (803,434) как x2, y2
# label = 1
# ЛКМ: добавил точку (825,351) как x1, y1
# ПКМ: добавил точку (866,440) как x2, y2
# label = 1
# ЛКМ: добавил точку (690,506) как x1, y1
# ПКМ: добавил точку (734,595) как x2, y2
# label = 1
# ЛКМ: добавил точку (818,610) как x1, y1
# ПКМ: добавил точку (852,658) как x2, y2
# label = 1
# ЛКМ: добавил точку (972,631) как x1, y1
# ПКМ: добавил точку (997,690) как x2, y2
# label = 1
# ЛКМ: добавил точку (1035,589) как x1, y1
# ПКМ: добавил точку (1069,655) как x2, y2
# label = 1
# ЛКМ: добавил точку (1184,1860) как x1, y1
# ПКМ: добавил точку (1222,1934) как x2, y2
# label = 1
# ЛКМ: добавил точку (1597,1702) как x1, y1
# ПКМ: добавил точку (1625,1773) как x2, y2
# label = 1
# ЛКМ: добавил точку (638,2133) как x1, y1
# ПКМ: добавил точку (668,2199) как x2, y2
# label = 0
# ЛКМ: добавил точку (516,2104) как x1, y1
# ПКМ: добавил точку (547,2187) как x2, y2
# label = 0
# ЛКМ: добавил точку (1198,1082) как x1, y1
# ПКМ: добавил точку (1253,1257) как x2, y2
# label = 0
# ЛКМ: добавил точку (759,735) как x1, y1
# ПКМ: добавил точку (830,892) как x2, y2
# label = 0
# ЛКМ: добавил точку (878,2155) как x1, y1
# ПКМ: добавил точку (910,2238) как x2, y2
# label = 0
# ЛКМ: добавил точку (1129,1917) как x1, y1
# ПКМ: добавил точку (1154,1986) как x2, y2
# label = 0
# ЛКМ: добавил точку (1287,1905) как x1, y1
# ПКМ: добавил точку (1323,1974) как x2, y2
# label = 0
# ЛКМ: добавил точку (785,1410) как x1, y1
# ПКМ: добавил точку (818,1482) как x2, y2
# label = 1
# ЛКМ: добавил точку (1573,1428) как x1, y1
# ПКМ: добавил точку (1602,1503) как x2, y2
# label = 1
# ЛКМ: добавил точку (1588,1035) как x1, y1
# ПКМ: добавил точку (1644,1160) как x2, y2
# label = 1
# ЛКМ: добавил точку (540,2425) как x1, y1
# ПКМ: добавил точку (565,2479) как x2, y2
# label = 1
# ЛКМ: добавил точку (274,198) как x1, y1
# ПКМ: добавил точку (307,264) как x2, y2
# label = 1
# ЛКМ: добавил точку (1063,1241) как x1, y1
# ПКМ: добавил точку (1104,1333) как x2, y2
# label = 1
# ЛКМ: добавил точку (1036,982) как x1, y1
# ПКМ: добавил точку (1077,1065) как x2, y2
# label = 1
# ЛКМ: добавил точку (1165,1372) как x1, y1
# ПКМ: добавил точку (1206,1464) как x2, y2
# label = 1
# ЛКМ: добавил точку (1460,1113) как x1, y1
# ПКМ: добавил точку (1501,1187) как x2, y2
# label = 1
# ЛКМ: добавил точку (1497,583) как x1, y1
# ПКМ: добавил точку (1531,655) как x2, y2
# label = 1
# ЛКМ: добавил точку (1551,437) как x1, y1
# ПКМ: добавил точку (1585,503) как x2, y2
# label = 1
# ЛКМ: добавил точку (791,1800) как x1, y1
# ПКМ: добавил точку (867,1937) как x2, y2
# label = 0
# ЛКМ: добавил точку (1321,1770) как x1, y1
# ПКМ: добавил точку (1396,1952) как x2, y2
# label = 0
# ЛКМ: добавил точку (1035,2287) как x1, y1
# ПКМ: добавил точку (1064,2341) как x2, y2
# label = 1
# ЛКМ: добавил точку (1181,775) как x1, y1
# ПКМ: добавил точку (1218,855) как x2, y2
# label = 1
# ЛКМ: добавил точку (263,1664) как x1, y1
# ПКМ: добавил точку (332,1833) как x2, y2
# label = 0
# ЛКМ: добавил точку (706,1526) как x1, y1
# ПКМ: добавил точку (731,1572) как x2, y2
# label = 1
# ЛКМ: добавил точку (673,2046) как x1, y1
# ПКМ: добавил точку (710,2114) как x2, y2
# label = 1
# ЛКМ: добавил точку (1040,2191) как x1, y1
# ПКМ: добавил точку (1061,2253) как x2, y2
# label = 1
# ЛКМ: добавил точку (539,542) как x1, y1
# ПКМ: добавил точку (565,576) как x2, y2
# label = 1
# ЛКМ: добавил точку (606,453) как x1, y1
# ПКМ: добавил точку (630,499) как x2, y2
# label = 1
# ЛКМ: добавил точку (770,632) как x1, y1
# ПКМ: добавил точку (801,684) как x2, y2
# label = 1
# ЛКМ: добавил точку (880,733) как x1, y1
# ПКМ: добавил точку (911,786) как x2, y2
# label = 1
# ЛКМ: добавил точку (1467,277) как x1, y1
# ПКМ: добавил точку (1499,336) как x2, y2
# label = 1
# ЛКМ: добавил точку (1493,669) как x1, y1
# ПКМ: добавил точку (1521,740) как x2, y2
# label = 1
# ЛКМ: добавил точку (1310,1060) как x1, y1
# ПКМ: добавил точку (1337,1106) как x2, y2
# label = 1
# ЛКМ: добавил точку (520,1861) как x1, y1
# ПКМ: добавил точку (548,1921) как x2, y2
# label = 1
# ЛКМ: добавил точку (505,1235) как x1, y1
# ПКМ: добавил точку (545,1324) как x2, y2
# label = 1
# ЛКМ: добавил точку (386,1048) как x1, y1
# ПКМ: добавил точку (418,1120) как x2, y2
# label = 1
# ЛКМ: добавил точку (870,1190) как x1, y1
# ПКМ: добавил точку (904,1265) как x2, y2
# label = 1
# ЛКМ: добавил точку (947,1607) как x1, y1
# ПКМ: добавил точку (983,1681) как x2, y2
# label = 1
# ЛКМ: добавил точку (1507,2247) как x1, y1
# ПКМ: добавил точку (1549,2336) как x2, y2
# label = 1
# ЛКМ: добавил точку (1589,277) как x1, y1
# ПКМ: добавил точку (1622,363) как x2, y2
# label = 1
# ЛКМ: добавил точку (1185,182) как x1, y1
# ПКМ: добавил точку (1217,241) как x2, y2
# label = 1
# ЛКМ: добавил точку (624,1512) как x1, y1
# ПКМ: добавил точку (661,1562) как x2, y2
# label = 1
# ЛКМ: добавил точку (1137,223) как x1, y1
# ПКМ: добавил точку (1185,304) как x2, y2
# label = 1
# ЛКМ: добавил точку (1640,140) как x1, y1
# ПКМ: добавил точку (1670,196) как x2, y2
# label = 1
# ЛКМ: добавил точку (1043,994) как x1, y1
# ПКМ: добавил точку (1061,1030) как x2, y2
# label = 1
# ЛКМ: добавил точку (1029,964) как x1, y1
# ПКМ: добавил точку (1045,997) как x2, y2
# label = 1
# ЛКМ: добавил точку (950,1363) как x1, y1
# ПКМ: добавил точку (977,1401) как x2, y2
# label = 1
# ЛКМ: добавил точку (1194,1134) как x1, y1
# ПКМ: добавил точку (1221,1178) как x2, y2
# label = 1
# ЛКМ: добавил точку (1303,1416) как x1, y1
# ПКМ: добавил точку (1331,1467) как x2, y2
# ЛКМ: добавил точку (1297,1404) как x1, y1
# ПКМ: добавил точку (1325,1461) как x2, y2
# label = 1
# ЛКМ: добавил точку (1289,1910) как x1, y1
# ПКМ: добавил точку (1317,1976) как x2, y2
# label = 1
# ЛКМ: добавил точку (1200,1211) как x1, y1
# ПКМ: добавил точку (1229,1256) как x2, y2
# label = 1
# ЛКМ: добавил точку (1223,292) как x1, y1
# ПКМ: добавил точку (1247,339) как x2, y2
# label = 1
# ЛКМ: добавил точку (1192,378) как x1, y1
# ПКМ: добавил точку (1221,437) как x2, y2
# label = 1
# ЛКМ: добавил точку (1493,193) как x1, y1
# ПКМ: добавил точку (1527,247) как x2, y2
# label = 1
# ЛКМ: добавил точку (1552,1157) как x1, y1
# ПКМ: добавил точку (1577,1202) как x2, y2
# label = 1
# ЛКМ: добавил точку (1596,1913) как x1, y1
# ПКМ: добавил точку (1634,1961) как x2, y2
# label = 1
# ЛКМ: добавил точку (814,2232) как x1, y1
# ПКМ: добавил точку (871,2309) как x2, y2
# label = 0
# ЛКМ: добавил точку (634,611) как x1, y1
# ПКМ: добавил точку (666,674) как x2, y2
# label = 1
# ЛКМ: добавил точку (597,1013) как x1, y1
# ПКМ: добавил точку (618,1056) как x2, y2
# label = 1
# ЛКМ: добавил точку (832,1119) как x1, y1
# ПКМ: добавил точку (856,1159) как x2, y2
# label = 1
# ЛКМ: добавил точку (959,2318) как x1, y1
# ПКМ: добавил точку (989,2370) как x2, y2
# label = 1
# ЛКМ: добавил точку (1168,2017) как x1, y1
# ПКМ: добавил точку (1205,2083) как x2, y2
# label = 1
# ЛКМ: добавил точку (1229,2066) как x1, y1
# ПКМ: добавил точку (1255,2115) как x2, y2
# label = 1
# ЛКМ: добавил точку (1350,1874) как x1, y1
# ПКМ: добавил точку (1387,1928) как x2, y2
# label = 1
# ЛКМ: добавил точку (1334,2095) как x1, y1
# ПКМ: добавил точку (1371,2149) как x2, y2
# label = 1
# ЛКМ: добавил точку (1613,1773) как x1, y1
# ПКМ: добавил точку (1654,1842) как x2, y2
# label = 1
# ЛКМ: добавил точку (320,284) как x1, y1
# ПКМ: добавил точку (350,339) как x2, y2
# label = 1
# ЛКМ: добавил точку (920,364) как x1, y1
# ПКМ: добавил точку (954,439) как x2, y2
# label = 0
# ЛКМ: добавил точку (1073,359) как x1, y1
# ПКМ: добавил точку (1112,442) как x2, y2
# label = 0
# ЛКМ: добавил точку (1408,382) как x1, y1
# ПКМ: добавил точку (1435,445) как x2, y2
# label = 0
# ЛКМ: добавил точку (1485,333) как x1, y1
# ПКМ: добавил точку (1524,407) как x2, y2
# label = 0
# ЛКМ: добавил точку (1614,252) как x1, y1
# ПКМ: добавил точку (1645,333) как x2, y2
# label = 0
# ЛКМ: добавил точку (914,1504) как x1, y1
# ПКМ: добавил точку (979,1650) как x2, y2
# label = 0
# ЛКМ: добавил точку (916,2083) как x1, y1
# ПКМ: добавил точку (983,2195) как x2, y2
# label = 0
# ЛКМ: добавил точку (1035,456) как x1, y1
# ПКМ: добавил точку (1073,530) как x2, y2
# label = 1
# ЛКМ: добавил точку (1098,391) как x1, y1
# ПКМ: добавил точку (1141,450) как x2, y2
# label = 1
# ЛКМ: добавил точку (1278,311) как x1, y1
# ПКМ: добавил точку (1315,388) как x2, y2
# label = 1
# ЛКМ: добавил точку (1344,206) как x1, y1
# ПКМ: добавил точку (1375,253) как x2, y2
# label = 1
# ЛКМ: добавил точку (1500,382) как x1, y1
# ПКМ: добавил точку (1529,447) как x2, y2
# label = 1
# ЛКМ: добавил точку (1410,841) как x1, y1
# ПКМ: добавил точку (1444,915) как x2, y2
# label = 1
# ЛКМ: добавил точку (1563,1276) как x1, y1
# ПКМ: добавил точку (1595,1341) как x2, y2
# label = 1
# ЛКМ: добавил точку (524,1957) как x1, y1
# ПКМ: добавил точку (557,2006) как x2, y2
# label = 1
# ЛКМ: добавил точку (372,1381) как x1, y1
# ПКМ: добавил точку (436,1495) как x2, y2
# label = 0
# ЛКМ: добавил точку (382,949) как x1, y1
# ПКМ: добавил точку (443,1069) как x2, y2
# label = 0
# ЛКМ: добавил точку (930,943) как x1, y1
# ПКМ: добавил точку (1003,1100) как x2, y2
# label = 0
# ЛКМ: добавил точку (887,1991) как x1, y1
# ПКМ: добавил точку (938,2108) как x2, y2
# label = 0
# ЛКМ: добавил точку (741,2502) как x1, y1
# ПКМ: добавил точку (791,2601) как x2, y2
# label = 0
# ЛКМ: добавил точку (904,1407) как x1, y1
# ПКМ: добавил точку (942,1476) как x2, y2
# label = 0
# ЛКМ: добавил точку (819,1776) как x1, y1
# ПКМ: добавил точку (858,1855) как x2, y2
# label = 0
# ЛКМ: добавил точку (1092,1562) как x1, y1
# ПКМ: добавил точку (1130,1637) как x2, y2
# label = 0
# ЛКМ: добавил точку (1217,1855) как x1, y1
# ПКМ: добавил точку (1251,1950) как x2, y2
# label = 0
# ЛКМ: добавил точку (1310,339) как x1, y1
# ПКМ: добавил точку (1339,391) как x2, y2
# label = 1
# ЛКМ: добавил точку (1321,206) как x1, y1
# ПКМ: добавил точку (1354,250) как x2, y2
# label = 1
# ЛКМ: добавил точку (1134,684) как x1, y1
# ПКМ: добавил точку (1210,804) как x2, y2
# label = 0
# ЛКМ: добавил точку (1130,419) как x1, y1
# ПКМ: добавил точку (1170,482) как x2, y2
# label = 1
# ЛКМ: добавил точку (1048,109) как x1, y1
# ПКМ: добавил точку (1077,155) как x2, y2
# label = 1
# ЛКМ: добавил точку (653,1093) как x1, y1
# ПКМ: добавил точку (677,1130) как x2, y2
# label = 1
# ЛКМ: добавил точку (330,318) как x1, y1
# ПКМ: добавил точку (364,384) как x2, y2
# label = 1
# ЛКМ: добавил точку (1626,2262) как x1, y1
# ПКМ: добавил точку (1662,2318) как x2, y2
# label = 1
# Сохранены все тензоры и лейблы

# %% [markdown]
# ## Обучение

# %% [markdown]
# Функция обучения

# %%
def train(
        model: nn.Module,
        data_loader: DataLoader,
        optimizer: Optimizer,
        loss_fn,
        device: torch.device,
) -> tuple[float, float]:
    model.train()

    total_loss = 0
    total = 0
    correct = 0

    for x, y in tqdm(data_loader, desc="Train"):
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()

        output = model(x)

        loss = loss_fn(output, y)

        loss.backward()

        total_loss += loss.item()

        optimizer.step()

        _, y_pred = torch.max(output, 1)
        total += y.size(0)
        correct += (y_pred == y).sum().item()

    return total_loss / len(data_loader), correct / total

# %% [markdown]
# Функция для валидации

# %%
@torch.inference_mode()
def evaluate(
        model: nn.Module, data_loader: DataLoader, loss_fn, device: torch.device
) -> tuple[float, float]:
    model.eval()

    total_loss = 0
    total = 0
    correct = 0

    for x, y in tqdm(data_loader, desc="Evaluate"):
        x, y = x.to(device), y.to(device)

        output = model(x)

        loss = loss_fn(output, y)

        total_loss += loss.item()

        _, y_pred = torch.max(output, 1)
        total += y.size(0)
        correct += (y_pred == y).sum().item()

    return total_loss / len(data_loader), correct / total

# %% [markdown]
# Функция для вывода статистики

# %%
def plot_stats(
        train_loss: list[float],
        valid_loss: list[float],
        train_accuracy: list[float],
        valid_accuracy: list[float],
        title: str,
):
    plt.figure(figsize=(16, 8))

    plt.title(title + " loss")

    plt.plot(train_loss, label="Train loss")
    plt.plot(valid_loss, label="Valid loss")
    plt.legend()
    plt.grid()

    plt.show()

    plt.figure(figsize=(16, 8))

    plt.title(title + " accuracy")

    plt.plot(train_accuracy, label="Train accuracy")
    plt.plot(valid_accuracy, label="Valid accuracy")
    plt.legend()
    plt.grid()

    plt.show()

# %% [markdown]
# Функция для цикла обучения и валидации

# %%
def whole_train_valid_cycle(
        model, train_loader, valid_loader, optimizer, loss_fn, scheduler, device, threshold, title
):
    train_loss_history, valid_loss_history = [], []
    train_accuracy_history, valid_accuracy_history = [], []

    for epoch in range(100):
        train_loss, train_accuracy = train(
            model, train_loader, optimizer, loss_fn, device
        )
        valid_loss, valid_accuracy = evaluate(model, valid_loader, loss_fn, device)

        train_loss_history.append(train_loss)
        valid_loss_history.append(valid_loss)

        train_accuracy_history.append(train_accuracy)
        valid_accuracy_history.append(valid_accuracy)

        clear_output(wait=True)

        plot_stats(
            train_loss_history,
            valid_loss_history,
            train_accuracy_history,
            valid_accuracy_history,
            title,
        )

        scheduler.step()

        if valid_accuracy >= threshold:
            break

# %% [markdown]
# Запуск обучения

# %%
images = torch.load('CV_data/Train/images.pt')
labels = torch.load('CV_data/Train/labels.pt')

if not isinstance(labels, torch.Tensor):
    labels = torch.tensor(labels)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

full_dataset = TensorDataset(images, labels)

val_ratio = 0.2
val_size = int(len(full_dataset) * val_ratio)
train_size = len(full_dataset) - val_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

model = BaseCNN(input_size=24).to(device)

optimizer = Adam(model.parameters(), lr=1e-3)
scheduler = StepLR(optimizer, step_size=20, gamma=0.1)

loss_fn = nn.CrossEntropyLoss()

whole_train_valid_cycle(
    model, train_loader, valid_loader, optimizer, loss_fn, scheduler, device, threshold=0.95, title='CNN'
)

torch.save(model.state_dict(), "CV_data/model.pt")

# %% [markdown]
# ## Инференс

# %%
images = torch.load('CV_data/Train/images.pt')
labels = torch.load('CV_data/Train/labels.pt')

if not isinstance(labels, torch.Tensor):
    labels = torch.tensor(labels)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

full_dataset = TensorDataset(images, labels)

val_ratio = 0.2
val_size = int(len(full_dataset) * val_ratio)
train_size = len(full_dataset) - val_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

model = BaseCNN(input_size=24).to(device)
model.load_state_dict(torch.load('CV_data/model.pt'))
model.eval()

all_logits = []
all_preds = []
all_labels = []
all_features = []

with torch.no_grad():
    for batch_imgs, batch_labels in val_loader:
        batch_imgs, batch_labels = batch_imgs.to(device), batch_labels.to(device)
        logits, features = model(batch_imgs, return_features=True)
        preds = torch.argmax(F.softmax(logits, dim=1), dim=1)

        all_logits.append(logits.cpu())
        all_preds.append(preds.cpu())
        all_labels.append(batch_labels.cpu())
        all_features.append(features.cpu())
        
all_logits = torch.cat(all_logits)
all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)
all_features = torch.cat(all_features)

print(f'Accuracy - {round((all_preds==all_labels).float().mean().item(),2)}')
# Out:
# Accuracy - 0.88

# %% [markdown]
# Посмотрим на фичи

# %%
images = torch.load('CV_data/Train/images.pt')
img = images[4].unsqueeze(0).to(device)

model = BaseCNN(input_size=24).to(device)
model.load_state_dict(torch.load('CV_data/model.pt'))
model.eval()

with torch.no_grad():
    x = model.relu(model.conv1(img))
    x = model.pool(x)
    x = model.relu(model.conv2(x))
    features = model.pool(x)

features = features.squeeze(0).cpu()

fig, axes = plt.subplots(4, 4, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(features[i], cmap='gray')
    ax.set_title(f'Канал {i}')
    ax.axis('off')

plt.suptitle('Активации после последнего сверточного слоя')
plt.tight_layout()
plt.show()
